# %%
import pandas as pd

# %%
df = pd.read_csv("../results/assignment7.csv")
df
# Out:
#    problem                                       method   i  score       time  \
# 0     TSPA  large neighborhood search with local search   0  69207  15.531287
# 1     TSPA  large neighborhood search with local search   1  69528   1.952785
# 2     TSPA  large neighborhood search with local search   2  69207   1.951817
# 3     TSPA  large neighborhood search with local search   3  69331   1.947407
# 4     TSPA  large neighborhood search with local search   4  69643   1.938822
# ..     ...                                          ...  ..    ...        ...
# 79    TSPB                    large neighborhood search  16  44154   2.340102
# 80    TSPB                    large neighborhood search  17  44356   2.335878
# 81    TSPB                    large neighborhood search  18  44356   2.335475
# 82    TSPB                    large neighborhood search  19  44356   2.345067
# 83    TSPB                    large neighborhood search  20  44305   2.335103
#
#      iter
# 0   119.0
# ...

# %%
grouped = df.groupby(['problem', 'method'])
best_results = grouped['score'].agg(['min', 'max', 'mean'])
