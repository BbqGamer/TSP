# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('ggplot')

# %%
df_rest = pd.read_csv('../results/assignment3-rest.csv')

# %%
df_rest[df_rest["problem"]=="TSPA"][["problem","method", "score", "time", "iter"]].groupby(["problem","method"]).agg(["mean", "min", "max"]).sort_values(by=("score", "mean"), ascending=True).plot(kind="bar", y="score", title="TSPA", figsize=(10, 5), )
# Out:
# <Axes: title={'center': 'TSPA'}, xlabel='problem,method'>

# %%
df3 = pd.read_csv('../results/assignment3.csv')

# %%
df3[df3["problem"]=="TSPA"][["problem","method", "score", "time", "iter"]].groupby(["problem","method"]).agg(["mean", "min", "max"]).sort_values(by=("score", "mean"), ascending=False).plot(kind="bar", y="score", title="TSPA", figsize=(10, 5))
# Out:
# <Axes: title={'center': 'TSPA'}, xlabel='problem,method'>

# %%
df3[df3["problem"]=="TSPA"][["problem","method", "score", "time", "iter"]].groupby(["problem","method"]).agg(["mean", "min", "max"]).sort_values(by=("score", "mean"), ascending=True)
# Out:
#                                            score                    time  \
#                                             mean    min    max      mean
# problem method
# TSPA    intra_edge_steepest_heuristic  71589.875  70098  73287  0.001483
#         intra_edge_greedy_heuristic    71607.695  70098  73508  0.017202
#         intra_node_steepest_heuristic  72289.390  70944  73656  0.001786
#         intra_node_greedy_heuristic    72290.475  70944  73656  0.006110
#         intra_edge_greedy_random       75600.000  75600  75600  0.278325
#         intra_edge_steepest_random     76529.000  76529  76529  0.013742
#         intra_node_greedy_random       83332.000  83332  83332  0.316289
#         intra_node_steepest_random     87801.000  87801  87801  0.059923
#
#                                                               iter
#                                             min       max     mean  min  max
# problem method
# TSPA    intra_edge_steepest_heuristic  0.000243  0.012076    8.740    3   17
#         intra_edge_greedy_heuristic    0.002855  0.048561   10.605    2   26
#         intra_node_steepest_heuristic  0.000238  0.009533    4.525    1   12
#         intra_node_greedy_heuristic    0.001438  0.023553    4.980    1   18
#         intra_edge_greedy_random       0.166902  0.490466  401.000  401  401
#         intra_edge_steepest_random     0.009286  0.028872  149.000  149  149
#         intra_node_greedy_random       0.179658  0.746241  441.000  441  441
#         intra_node_steepest_random     0.039888  0.134001  182.000  182  182

# %%
df4 = pd.read_csv('../results/assignment4_5.csv')

# %%
improved = [["problem","method", "score", "time", "iter"]].groupby(["problem","method"]).mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 improved = [["problem","method", "score", "time", "iter"]].groupby(["problem","method"]).mean()
#
# AttributeError: 'list' object has no attribute 'groupby'

# %%
df4[df4["problem"]=="TSPA"][["problem","method", "score", "time", "iter"]].groupby(["problem","method"]).agg(["mean", "min", "max"]).sort_values(by=("score", "mean"), ascending=True)
# Out:
#                                                 score                    time  \
#                                                  mean    min    max      mean
# problem method
# TSPA    IMPROVED_intra_edge_steepest_random  78347.37  73535  84433  0.004161
#
#                                                                    iter       \
#                                                  min       max     mean  min
# problem method
# TSPA    IMPROVED_intra_edge_steepest_random  0.00326  0.009122  124.735  105
#
#
#                                              max
# problem method
# TSPA    IMPROVED_intra_edge_steepest_random  146

# %%
improved
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 improved
#
# NameError: name 'improved' is not defined

# %%
df_all = pd.concat([df3, df4]) #, df_rest])

# %%
df_all["time"] = round(df_all["time"]*100, 2)

# %%
df_plot = df_all[df_all["problem"]=="TSPB"][["problem","method", "score", "time", "iter"]].groupby(["problem","method"]).agg(["mean", "min", "max"]).sort_values(by=("iter", "mean"), ascending=True).round(2)[["iter"]]
df_plot
# Out:
#                                                iter
#                                                mean  min  max
# problem method
# TSPB    intra_node_steepest_heuristic          9.71    5   17
#         intra_edge_steepest_heuristic         10.06    5   16
#         intra_node_greedy_heuristic           10.68    6   21
#         intra_edge_greedy_heuristic           11.40    5   27
#         IMPROVED_intra_edge_steepest_random  132.17  115  155
#         intra_edge_steepest_random           139.00  139  139
#         intra_node_steepest_random           156.00  156  156
#         intra_node_greedy_random             368.00  368  368
#         intra_edge_greedy_random             454.00  454  454

# %%
import dataframe_image as dfi
dfi.export(df_plot, 'df_styled.png')
