# %%
import pandas as pd

# %%
df = pd.read_csv('../results/assignment3.csv')

# %%
df[["problem","method", "score", "time", "iter"]].groupby(["problem","method"]).mean()
# Out:
#                                            score      time     iter
# problem method
# TSPA    intra_edge_greedy_heuristic    71607.695  0.017202   10.605
#         intra_edge_greedy_random       75600.000  0.278325  401.000
#         intra_edge_steepest_heuristic  71589.875  0.001483    8.740
#         intra_edge_steepest_random     76529.000  0.013742  149.000
#         intra_node_greedy_heuristic    72290.475  0.006110    4.980
#         intra_node_greedy_random       83332.000  0.316289  441.000
#         intra_node_steepest_heuristic  72289.390  0.001786    4.525
#         intra_node_steepest_random     87801.000  0.059923  182.000
# TSPB    intra_edge_greedy_heuristic    50692.245  0.023197   11.405
#         intra_edge_greedy_random       48694.000  0.371627  454.000
#         intra_edge_steepest_heuristic  50673.450  0.001689   10.060
#         intra_edge_steepest_random     48026.000  0.022085  139.000
#         intra_node_greedy_heuristic    50799.020  0.019526   10.675
# ...

# %%
df4 = pd.read_csv('../results/assignment4_4.csv')

# %%
df4[["problem","method", "score", "time", "iter"]].groupby(["problem","method"]).mean()
# Out:
#                                         score      time    iter
# problem method
# TSPA    intra_edge_steepest_random  75989.190  0.011428  128.43
# TSPB    intra_edge_steepest_random  48470.885  0.010655  133.14

# %%
df4[["problem","method", "score", "time", "iter"]].groupby(["problem","method"]).mean()
# Out:
#                                         score      time    iter
# problem method
# TSPA    intra_edge_steepest_random  84409.195  0.005778  119.19
# TSPB    intra_edge_steepest_random  50039.055  0.005634  127.56
